# %% [markdown]
# # Disease Risk Prediction Model Training Template
# ## PyCaret + SHAP Pipeline
#
# This notebook template is used for training each disease prediction model.
# Duplicate this for: diabetes, heart disease, and CKD modules.

# %%
# Cell 1 — Install dependencies
# !pip install pycaret[full] shap optuna --quiet

# %%
# Cell 2 — Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

MODELS_PATH = '/content/drive/MyDrive/healthai/models/'
import os
os.makedirs(MODELS_PATH, exist_ok=True)

# %%
# Cell 3 — Verify installations
import pycaret
import shap
print(f'PyCaret  {pycaret.__version__}')
print(f'SHAP     {shap.__version__}')
print('Environment ready ✓')

# %%
# Cell 4 — Load Dataset
import pandas as pd

# TODO: Replace with actual dataset path
# df = pd.read_csv('path/to/dataset.csv')
# print(df.shape)
# df.head()

# %%
# Cell 5 — PyCaret Setup
from pycaret.classification import *

# TODO: Update target column name
# clf = setup(data=df, target='target_column', session_id=42, verbose=False)

# %%
# Cell 6 — Compare Models
# best_model = compare_models(sort='AUC', n_select=1)

# %%
# Cell 7 — Tune Model
# tuned_model = tune_model(best_model, optimize='AUC')

# %%
# Cell 8 — Evaluate Model
# evaluate_model(tuned_model)

# %%
# Cell 9 — Save Model
# save_model(tuned_model, MODELS_PATH + 'disease_model')
# print(f'Model saved to {MODELS_PATH}')

# %%
# Cell 10 — SHAP Explainer
# import shap
# explainer = shap.TreeExplainer(tuned_model)
# Save explainer if needed for later use
